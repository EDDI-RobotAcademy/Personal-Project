# %%
from flask import Flask, render_template, redirect
app = Flask(__name__)

import time 
import serial

import threading

ser = serial.Serial('/dev/ttyACM0', 9600)

lock = threading.Lock()


@app.route("/")
def Fan_Project():
    return render_template('Fan_Project.html')

@app.route("/Manual_Mode")
def Manual_Mode():
    lock.acquire()
    ser.write(b'1')
    lock.release()
    return render_template('Manual_Mode.html')

@app.route("/Auto_Mode")
def Auto_Mode():
    lock.acquire()
    ser.write(b'2')
    lock.release()
    return render_template('Auto_Mode.html')

@app.route('/Servo_Start')
def manual_servo_start():
    lock.acquire()
    ser.write(b'3')
    lock.release()
    return render_template('Manual_Mode.html')
    
@app.route('/Servo_Stop')
def manual_servo_stop():
    lock.acquire()
    ser.write(b'4')
    lock.release()
    return render_template('Manual_Mode.html')

@app.route('/Bldc_Low')
def bldc_low():
    lock.acquire()
    ser.write(b'5')
    lock.release()
    return render_template('Manual_Mode.html')

@app.route('/Bldc_Middle')
def bldc_middle():
    lock.acquire()
    ser.write(b'6')
    lock.release()
    return render_template('Manual_Mode.html')

@app.route('/Bldc_High')
def bldc_high():
    lock.acquire()
    ser.write(b'7')
    lock.release()
    return render_template('Manual_Mode.html')

@app.route('/Bldc_Stop')
def bldc_stop():
    lock.acquire()
    ser.write(b'8')
    lock.release()
    return render_template('Manual_Mode.html')

@app.route('/Back')
def back():
    lock.acquire()
    ser.write(b'9')
    lock.release()
    return render_template('Fan_Project.html')


if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [02/Jul/2022 05:00:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Jul/2022 05:00:29] "GET /Manual_Mode HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Jul/2022 05:00:29] "GET /style.css HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Jul/2022 05:00:32] "GET /Servo_Start HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Jul/2022 05:00:32] "GET /style.css HTTP/1.1" 404 -
